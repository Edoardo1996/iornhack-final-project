# %%
import pandas as pd
import numpy as np
import re
from utils import cleaning

# %%
df = pd.read_csv("dataset/world_energy_consumption.csv")

# %%
df.head()
# Out:
#        country  year iso_code  population  gdp  biofuel_cons_change_pct  \
# 0  Afghanistan  1900      AFG   4832414.0  NaN                      NaN
# 1  Afghanistan  1901      AFG   4879685.0  NaN                      NaN
# 2  Afghanistan  1902      AFG   4935122.0  NaN                      NaN
# 3  Afghanistan  1903      AFG   4998861.0  NaN                      NaN
# 4  Afghanistan  1904      AFG   5063419.0  NaN                      NaN
#
#    biofuel_cons_change_twh  biofuel_cons_per_capita  biofuel_consumption  \
# 0                      NaN                      NaN                  NaN
# 1                      NaN                      NaN                  NaN
# 2                      NaN                      NaN                  NaN
# 3                      NaN                      NaN                  NaN
# 4                      NaN                      NaN                  NaN
#
#    biofuel_elec_per_capita  ...  solar_share_elec  solar_share_energy  \
# 0                      NaN  ...               NaN                 NaN
# 1                      NaN  ...               NaN                 NaN
# 2                      NaN  ...               NaN                 NaN
# 3                      NaN  ...               NaN                 NaN
# 4                      NaN  ...               NaN                 NaN
#
#    wind_cons_change_pct  wind_cons_change_twh  wind_consumption  \
# 0                   NaN                   NaN               NaN
# 1                   NaN                   NaN               NaN
# 2                   NaN                   NaN               NaN
# 3                   NaN                   NaN               NaN
# 4                   NaN                   NaN               NaN
#
#    wind_elec_per_capita  wind_electricity  wind_energy_per_capita  \
# 0                   NaN               NaN                     NaN
# 1                   NaN               NaN                     NaN
# 2                   NaN               NaN                     NaN
# 3                   NaN               NaN                     NaN
# 4                   NaN               NaN                     NaN
#
#    wind_share_elec  wind_share_energy
# 0              NaN                NaN
# 1              NaN                NaN
# 2              NaN                NaN
# 3              NaN                NaN
# 4              NaN                NaN
#
# [5 rows x 128 columns]

# %%
df.columns
# Out:
# Index(['country', 'year', 'iso_code', 'population', 'gdp',
#        'biofuel_cons_change_pct', 'biofuel_cons_change_twh',
#        'biofuel_cons_per_capita', 'biofuel_consumption',
#        'biofuel_elec_per_capita',
#        ...
#        'solar_share_elec', 'solar_share_energy', 'wind_cons_change_pct',
#        'wind_cons_change_twh', 'wind_consumption', 'wind_elec_per_capita',
#        'wind_electricity', 'wind_energy_per_capita', 'wind_share_elec',
#        'wind_share_energy'],
#       dtype='object', length=128)

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22343 entries, 0 to 22342
# Data columns (total 128 columns):
#  #    Column                                        Dtype
# ---   ------                                        -----
#  0    country                                       object
#  1    year                                          int64
#  2    iso_code                                      object
#  3    population                                    float64
#  4    gdp                                           float64
#  5    biofuel_cons_change_pct                       float64
#  6    biofuel_cons_change_twh                       float64
#  7    biofuel_cons_per_capita                       float64
#  8    biofuel_consumption                           float64
#  9    biofuel_elec_per_capita                       float64
#  10   biofuel_electricity                           float64
#  11   biofuel_share_elec                            float64
#  12   biofuel_share_energy                          float64
#  13   carbon_intensity_elec                         float64
#  14   coal_cons_change_pct                          float64
#  15   coal_cons_change_twh                          float64
#  16   coal_cons_per_capita                          float64
#  17   coal_consumption                              float64
#  18   coal_elec_per_capita                          float64
#  19   coal_electricity                              float64
#  20   coal_prod_change_pct                          float64
#  21   coal_prod_change_twh                          float64
#  22   coal_prod_per_capita                          float64
#  23   coal_production                               float64
#  24   coal_share_elec                               float64
#  25   coal_share_energy                             float64
#  26   electricity_demand                            float64
#  27   electricity_generation                        float64
#  28   energy_cons_change_pct                        float64
#  29   energy_cons_change_twh                        float64
#  30   energy_per_capita                             float64
#  31   energy_per_gdp                                float64
#  32   fossil_cons_change_pct                        float64
#  33   fossil_cons_change_twh                        float64
#  34   fossil_elec_per_capita                        float64
#  35   fossil_electricity                            float64
#  36   fossil_energy_per_capita                      float64
#  37   fossil_fuel_consumption                       float64
#  38   fossil_share_elec                             float64
#  39   fossil_share_energy                           float64
#  40   gas_cons_change_pct                           float64
#  41   gas_cons_change_twh                           float64
#  42   gas_consumption                               float64
#  43   gas_elec_per_capita                           float64
#  44   gas_electricity                               float64
#  45   gas_energy_per_capita                         float64
#  46   gas_prod_change_pct                           float64
#  47   gas_prod_change_twh                           float64
#  48   gas_prod_per_capita                           float64
#  49   gas_production                                float64
#  50   gas_share_elec                                float64
#  51   gas_share_energy                              float64
#  52   greenhouse_gas_emissions                      float64
#  53   hydro_cons_change_pct                         float64
#  54   hydro_cons_change_twh                         float64
#  55   hydro_consumption                             float64
#  56   hydro_elec_per_capita                         float64
#  57   hydro_electricity                             float64
#  58   hydro_energy_per_capita                       float64
#  59   hydro_share_elec                              float64
#  60   hydro_share_energy                            float64
#  61   low_carbon_cons_change_pct                    float64
#  62   low_carbon_cons_change_twh                    float64
#  63   low_carbon_consumption                        float64
#  64   low_carbon_elec_per_capita                    float64
#  65   low_carbon_electricity                        float64
#  66   low_carbon_energy_per_capita                  float64
#  67   low_carbon_share_elec                         float64
#  68   low_carbon_share_energy                       float64
#  69   net_elec_imports                              float64
#  70   net_elec_imports_share_demand                 float64
#  71   nuclear_cons_change_pct                       float64
#  72   nuclear_cons_change_twh                       float64
#  73   nuclear_consumption                           float64
#  74   nuclear_elec_per_capita                       float64
#  75   nuclear_electricity                           float64
#  76   nuclear_energy_per_capita                     float64
#  77   nuclear_share_elec                            float64
#  78   nuclear_share_energy                          float64
#  79   oil_cons_change_pct                           float64
#  80   oil_cons_change_twh                           float64
#  81   oil_consumption                               float64
#  82   oil_elec_per_capita                           float64
#  83   oil_electricity                               float64
#  84   oil_energy_per_capita                         float64
#  85   oil_prod_change_pct                           float64
#  86   oil_prod_change_twh                           float64
#  87   oil_prod_per_capita                           float64
#  88   oil_production                                float64
#  89   oil_share_elec                                float64
#  90   oil_share_energy                              float64
#  91   other_renewable_consumption                   float64
#  92   other_renewable_electricity                   float64
#  93   other_renewable_exc_biofuel_electricity       float64
#  94   other_renewables_cons_change_pct              float64
#  95   other_renewables_cons_change_twh              float64
#  96   other_renewables_elec_per_capita              float64
#  97   other_renewables_elec_per_capita_exc_biofuel  float64
#  98   other_renewables_energy_per_capita            float64
#  99   other_renewables_share_elec                   float64
#  100  other_renewables_share_elec_exc_biofuel       float64
#  101  other_renewables_share_energy                 float64
#  102  per_capita_electricity                        float64
#  103  primary_energy_consumption                    float64
#  104  renewables_cons_change_pct                    float64
#  105  renewables_cons_change_twh                    float64
#  106  renewables_consumption                        float64
#  107  renewables_elec_per_capita                    float64
#  108  renewables_electricity                        float64
#  109  renewables_energy_per_capita                  float64
#  110  renewables_share_elec                         float64
#  111  renewables_share_energy                       float64
#  112  solar_cons_change_pct                         float64
#  113  solar_cons_change_twh                         float64
#  114  solar_consumption                             float64
#  115  solar_elec_per_capita                         float64
#  116  solar_electricity                             float64
#  117  solar_energy_per_capita                       float64
#  118  solar_share_elec                              float64
#  119  solar_share_energy                            float64
#  120  wind_cons_change_pct                          float64
#  121  wind_cons_change_twh                          float64
#  122  wind_consumption                              float64
#  123  wind_elec_per_capita                          float64
#  124  wind_electricity                              float64
#  125  wind_energy_per_capita                        float64
#  126  wind_share_elec                               float64
#  127  wind_share_energy                             float64
# dtypes: float64(125), int64(1), object(2)
# memory usage: 21.8+ MB

# %%
# Dump value counts
cleaning.dump_value_counts('data_expl/', df)

# %% [markdown]
# Try to subdivide the dataset in other sub-dataset.
# 1. One will be the ones with all the primary energy productions, consumption,
#    shares etc.
# 2. Other will be with overall measures such as overall energy production
# <br><br>
# After that, an EDA will be performed, it will also be easier to understand the <br>
# dataset's behaviour (missing data per country, missing data per energy src etc.) <br>
# These sub-dataset can be indexed by the identifiers that reports general id like <br>
# country, population and gdp.

# %%
# All energy sources
energy_src = ['biofuel', 'coal', 'gas', 'oil', 'hydro', 'nuclear',
               'other_renewable', 'other_renewable_exc_biofuel', 'solar', 'wind', 
               'fossil', 'low_carbon', 'renewables'] # Primary energy sources
overall_energy_measures = ['energy_cons_change_pct', 'energy_cons_change_pct', 
                    'carbon_intensity_elec', 'electricity_generation', 
                    'fossil_electricity', 'renewables_electricity',
                    'energy_per_gdp', 'energy_per_capita', 
                    'per_capita_electricity', 'primary_energy_consumption']
identifiers = ['iso_code', 'country', 'year', 'population', 'gdp', ]

# %% [markdown]
# Which kind of data is available for energy src?

# %%
# Divide pure energy src from aggregated ones
pure_energy_src = ['biofuel', 'coal', 'gas', 'hydro', 'nuclear', 'oil', 'solar', 'wind']
aggragated_energy_src = ['fossil', 'low_carbon', 'other_renewable', 'other_renewable_exc_biofuel', 'renewables']

# %%
# Create a energy src dataset for exploration
pure_energy_src_data_cols = ['energy_source', 'description', '#_of_measures_available']

# %%
# Std consumption and production names:
# production --> prod
# consumption --> cons
# electricity --> elec
df_std = df.copy()

df_std.columns = df.columns.str.replace('production', 'prod').str.replace('electricity', 'elec').str.replace('consumption', 'cons')

# %%
# How many measures are available for each energy srcs
n_measures = [([col for col in df_std.columns if energy == col.split('_')[0]]) for energy in pure_energy_src]
measures_per_energy = {pure_energy_src[i]: n_measures[i] for i in range(len(n_measures))}
measures_per_energy
# Out:
# {'biofuel': ['biofuel_cons_change_pct',
#   'biofuel_cons_change_twh',
#   'biofuel_cons_per_capita',
#   'biofuel_cons',
#   'biofuel_elec_per_capita',
#   'biofuel_elec',
#   'biofuel_share_elec',
#   'biofuel_share_energy'],
#  'coal': ['coal_cons_change_pct',
#   'coal_cons_change_twh',
#   'coal_cons_per_capita',
#   'coal_cons',
#   'coal_elec_per_capita',
#   'coal_elec',
#   'coal_prod_change_pct',
#   'coal_prod_change_twh',
#   'coal_prod_per_capita',
#   'coal_prod',
#   'coal_share_elec',
#   'coal_share_energy'],
#  'gas': ['gas_cons_change_pct',
#   'gas_cons_change_twh',
#   'gas_cons',
#   'gas_elec_per_capita',
#   'gas_elec',
#   'gas_energy_per_capita',
#   'gas_prod_change_pct',
#   'gas_prod_change_twh',
#   'gas_prod_per_capita',
#   'gas_prod',
#   'gas_share_elec',
#   'gas_share_energy'],
#  'hydro': ['hydro_cons_change_pct',
#   'hydro_cons_change_twh',
#   'hydro_cons',
#   'hydro_elec_per_capita',
#   'hydro_elec',
#   'hydro_energy_per_capita',
#   'hydro_share_elec',
#   'hydro_share_energy'],
#  'nuclear': ['nuclear_cons_change_pct',
#   'nuclear_cons_change_twh',
#   'nuclear_cons',
#   'nuclear_elec_per_capita',
#   'nuclear_elec',
#   'nuclear_energy_per_capita',
#   'nuclear_share_elec',
#   'nuclear_share_energy'],
#  'oil': ['oil_cons_change_pct',
#   'oil_cons_change_twh',
#   'oil_cons',
#   'oil_elec_per_capita',
#   'oil_elec',
#   'oil_energy_per_capita',
#   'oil_prod_change_pct',
#   'oil_prod_change_twh',
#   'oil_prod_per_capita',
#   'oil_prod',
#   'oil_share_elec',
#   'oil_share_energy'],
#  'solar': ['solar_cons_change_pct',
#   'solar_cons_change_twh',
#   'solar_cons',
#   'solar_elec_per_capita',
#   'solar_elec',
#   'solar_energy_per_capita',
#   'solar_share_elec',
#   'solar_share_energy'],
#  'wind': ['wind_cons_change_pct',
#   'wind_cons_change_twh',
#   'wind_cons',
#   'wind_elec_per_capita',
#   'wind_elec',
#   'wind_energy_per_capita',
#   'wind_share_elec',
#   'wind_share_energy']}

# %% [markdown]
# For each pure energy src we have the following:
# 1. Consumption data **cons**
#    For **cons** data then we have
#    1. Primary fuel consumption if only **cons** in terawatt-hours
#    2. **change** --> representing annual change in energy src consumption
#       1. **change** can be percentatage with **pct**
#       2. **change** can be in terawatt-hours with **twh**
#    3. **per_capita** if measured in terwatt-hours per capita
# 2. Electricity consumption from the energy src with **elec**:
#    1. Pure electricity consumption if only **elec** in terawatt-hours
#    2. **per_capita** if electricity is measured per capita
# 3. **share** when accounting for the share among the other energy srcs:
#    1. could be **elec** referring to electricity consuption;
#    2. could be **energy** when accounting for energy srcs
# 4. **prod** accounts for prod (elec+thermal?) using the energy source:
#    1. if no additional keywords, is the overall production in terawatt hours
