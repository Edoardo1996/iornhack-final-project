# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import numpy as np
import scipy
import math
import collections
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# utils
from utils import cleaning, config, eda

# %%
# Load data and start formatting
sc_raw = cleaning.load_data(config.DB_SC_PATH)

# Format column name and change index
sc_prep = sc_raw.copy()
sc_prep = cleaning.format_data(sc_prep)


display(eda.report(sc_prep))
display(sc_prep.head())
# Out:
#                                    nan_count   dtype  unique
# city                                       0  object     102
# country                                    0  object      36
# smart_mobility                             0   int64     100
# smart_environment                          0   int64      98
# smart_government                           0   int64      98
# smart_economy                              0   int64      99
# smart_people                               0   int64      98
# smart_living                               0   int64      38
# smartcity_index                            0   int64     100
# smartcity_index_relative_edmonton          0   int64     102
#           city      country  smart_mobility  smart_environment  \
# id
# 1         Oslo       Norway            6480               6512
# 2       Bergen       Norway            7097               6876
# 3    Amsterdam  Netherlands            7540               5558
# ...
